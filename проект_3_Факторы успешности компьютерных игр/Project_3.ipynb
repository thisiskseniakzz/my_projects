# %% [markdown]
# # Определение факторов, влияющих на успешность компьютерных игр на основе исторических данных о продаже игр интернет-магазина «Стримчик»

# %% [markdown]
# - Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# - Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# - В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Этап-1.-Откроем-библиотеки,-загрузка-данных-и-первичное-изучение-данных" data-toc-modified-id="Этап-1.-Откроем-библиотеки,-загрузка-данных-и-первичное-изучение-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Этап 1. Откроем библиотеки, загрузка данных и первичное изучение данных</a></span><ul class="toc-item"><li><span><a href="#Загрузим-библиотеки" data-toc-modified-id="Загрузим-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузим библиотеки</a></span></li><li><span><a href="#Загрузим-датафрейм-и-проведем-первичный-его-анализ" data-toc-modified-id="Загрузим-датафрейм-и-проведем-первичный-его-анализ-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузим датафрейм и проведем первичный его анализ</a></span></li><li><span><a href="#Изучим-информацию" data-toc-modified-id="Изучим-информацию-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Изучим информацию</a></span></li><li><span><a href="#Посмотрим-на-пропуски-внимательнее" data-toc-modified-id="Посмотрим-на-пропуски-внимательнее-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Посмотрим на пропуски внимательнее</a></span></li><li><span><a href="#Проверим-датафрейм-на-наличие-дубликатов" data-toc-modified-id="Проверим-датафрейм-на-наличие-дубликатов-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверим датафрейм на наличие дубликатов</a></span></li><li><span><a href="#Выводы-по-этапу" data-toc-modified-id="Выводы-по-этапу-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Выводы по этапу</a></span></li></ul></li><li><span><a href="#Этап-2.-Предобработка-данных" data-toc-modified-id="Этап-2.-Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Этап 2. Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Поправим-регистр-столбцов." data-toc-modified-id="Поправим-регистр-столбцов.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Поправим регистр столбцов.</a></span></li><li><span><a href="#Преобразуем-типы-данных-в-столбцах" data-toc-modified-id="Преобразуем-типы-данных-в-столбцах-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Преобразуем типы данных в столбцах</a></span></li><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Работа с пропусками</a></span><ul class="toc-item"><li><span><a href="#Удалим-пропуски-в-'name'" data-toc-modified-id="Удалим-пропуски-в-'name'-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Удалим пропуски в 'name'</a></span></li><li><span><a href="#Удалим-пропуски-в-'year_of_release'" data-toc-modified-id="Удалим-пропуски-в-'year_of_release'-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Удалим пропуски в 'year_of_release'</a></span></li></ul></li><li><span><a href="#Коррекция-данных-по-рейтингу-('rating')" data-toc-modified-id="Коррекция-данных-по-рейтингу-('rating')-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Коррекция данных по рейтингу ('rating')</a></span></li><li><span><a href="#Добавление-дополнительного-столбца-по-суммарным-продажам-по-всем-регионам" data-toc-modified-id="Добавление-дополнительного-столбца-по-суммарным-продажам-по-всем-регионам-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Добавление дополнительного столбца по суммарным продажам по всем регионам</a></span></li><li><span><a href="#Посмотрим,-что-за-игры" data-toc-modified-id="Посмотрим,-что-за-игры-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Посмотрим, что за игры</a></span></li><li><span><a href="#Выводы-по-шагу" data-toc-modified-id="Выводы-по-шагу-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Выводы по шагу</a></span></li></ul></li><li><span><a href="#Этап-3.-Ислледовательский-анализ-данных" data-toc-modified-id="Этап-3.-Ислледовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Этап 3. Ислледовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределение-игр-по-годам-релиза" data-toc-modified-id="Распределение-игр-по-годам-релиза-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Распределение игр по годам релиза</a></span><ul class="toc-item"><li><span><a href="#Рассмотрим-как-менялись-продажи-по-платформам" data-toc-modified-id="Рассмотрим-как-менялись-продажи-по-платформам-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Рассмотрим как менялись продажи по платформам</a></span></li></ul></li><li><span><a href="#Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам." data-toc-modified-id="Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.</a></span><ul class="toc-item"><li><span><a href="#Визуализируем-продажи-по-платформам" data-toc-modified-id="Визуализируем-продажи-по-платформам-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Визуализируем продажи по платформам</a></span></li><li><span><a href="#Построим-график-по-всем-платформам." data-toc-modified-id="Построим-график-по-всем-платформам.-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Построим график по всем платформам.</a></span></li><li><span><a href="#Визуализируем-полученные-цифры" data-toc-modified-id="Визуализируем-полученные-цифры-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Визуализируем полученные цифры</a></span></li><li><span><a href="#График-ниже-покажет-как-раз-продажи-по-интересующим-нам-платформам,-просмотрим-их-динамику-на-исторической-арене,-мы-их-выявили-несколько-шагов-назад-это-'PS2',-'X360',-'PS3',-'Wii',-'DS',-'PS',-'PS4',-'GBA',-'PSP',-'3DS'" data-toc-modified-id="График-ниже-покажет-как-раз-продажи-по-интересующим-нам-платформам,-просмотрим-их-динамику-на-исторической-арене,-мы-их-выявили-несколько-шагов-назад-это-'PS2',-'X360',-'PS3',-'Wii',-'DS',-'PS',-'PS4',-'GBA',-'PSP',-'3DS'-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>График ниже покажет как раз продажи по интересующим нам платформам, просмотрим их динамику на исторической арене, мы их выявили несколько шагов назад это 'PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS', 'PS4', 'GBA', 'PSP', '3DS'</a></span></li><li><span><a href="#Посмотрим-на-первый-год-продаж-у-каждой-платформы-(первый-год-после-появления-платформы-на-рынке)" data-toc-modified-id="Посмотрим-на-первый-год-продаж-у-каждой-платформы-(первый-год-после-появления-платформы-на-рынке)-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Посмотрим на первый год продаж у каждой платформы (первый год после появления платформы на рынке)</a></span></li><li><span><a href="#Посчитаем-все-года,-когда-происходили-продажи-для-самых-популярных-платформ,-чтобы-определить-срок-жизни-платформы-в-среднем." data-toc-modified-id="Посчитаем-все-года,-когда-происходили-продажи-для-самых-популярных-платформ,-чтобы-определить-срок-жизни-платформы-в-среднем.-3.2.6"><span class="toc-item-num">3.2.6&nbsp;&nbsp;</span>Посчитаем все года, когда происходили продажи для самых популярных платформ, чтобы определить срок жизни платформы в среднем.</a></span></li></ul></li><li><span><a href="#Возьмите-данные-за-соответствующий-актуальный-период.-Актуальный-период-определите-самостоятельно-в-результате-исследования-предыдущих-вопросов.-Основной-фактор-—-эти-данные-помогут-построить-прогноз-на-2017-год." data-toc-modified-id="Возьмите-данные-за-соответствующий-актуальный-период.-Актуальный-период-определите-самостоятельно-в-результате-исследования-предыдущих-вопросов.-Основной-фактор-—-эти-данные-помогут-построить-прогноз-на-2017-год.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.</a></span><ul class="toc-item"><li><span><a href="#Актуальный-период-для-исследования" data-toc-modified-id="Актуальный-период-для-исследования-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Актуальный период для исследования</a></span></li><li><span><a href="#Если-до-этого-мы-выявляли-топ-10-по-продажам,-то-тут-посмотрим-на-динамику-продаж-платформ-за-конкретный-период-с-2012-по-2016-гг." data-toc-modified-id="Если-до-этого-мы-выявляли-топ-10-по-продажам,-то-тут-посмотрим-на-динамику-продаж-платформ-за-конкретный-период-с-2012-по-2016-гг.-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Если до этого мы выявляли топ 10 по продажам, то тут посмотрим на динамику продаж платформ за конкретный период с 2012 по 2016 гг.</a></span></li><li><span><a href="#Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат." data-toc-modified-id="Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат.-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.</a></span><ul class="toc-item"><li><span><a href="#Строим-boxplots-для-наших-платформ-по-продажам-игр" data-toc-modified-id="Строим-boxplots-для-наших-платформ-по-продажам-игр-3.3.3.1"><span class="toc-item-num">3.3.3.1&nbsp;&nbsp;</span>Строим boxplots для наших платформ по продажам игр</a></span></li></ul></li></ul></li><li><span><a href="#Влияние-на-продажи-внутри-одной-популярной-платформы-отзывов-пользователей-и-критиков" data-toc-modified-id="Влияние-на-продажи-внутри-одной-популярной-платформы-отзывов-пользователей-и-критиков-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Влияние на продажи внутри одной популярной платформы отзывов пользователей и критиков</a></span><ul class="toc-item"><li><span><a href="#Взаимосвязи-между-отзывами-и-продажами-для-PS4" data-toc-modified-id="Взаимосвязи-между-отзывами-и-продажами-для-PS4-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Взаимосвязи между отзывами и продажами для PS4</a></span></li><li><span><a href="#Взаимосвязи-между-отзывами-и-продажами-для-3DS" data-toc-modified-id="Взаимосвязи-между-отзывами-и-продажами-для-3DS-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Взаимосвязи между отзывами и продажами для 3DS</a></span></li><li><span><a href="#Взаимосвязи-между-отзывами-и-продажами-для-XOne" data-toc-modified-id="Взаимосвязи-между-отзывами-и-продажами-для-XOne-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Взаимосвязи между отзывами и продажами для XOne</a></span></li><li><span><a href="#Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?" data-toc-modified-id="Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?</a></span></li></ul></li><li><span><a href="#Выводы-по-шагу" data-toc-modified-id="Выводы-по-шагу-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы по шагу</a></span></li></ul></li><li><span><a href="#Этап-4.-Портрет-пользователя-каждого-региона" data-toc-modified-id="Этап-4.-Портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Этап 4. Портрет пользователя каждого региона</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Самые-популярные-жанры-(топ-5).-Поясните-разницу" data-toc-modified-id="Самые-популярные-жанры-(топ-5).-Поясните-разницу-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>Самые популярные жанры (топ-5). Поясните разницу</a></span></li><li><span><a href="#Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?" data-toc-modified-id="Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>Влияет ли рейтинг ESRB на продажи в отдельном регионе?</a></span></li></ul></li><li><span><a href="#Выводы-по-шагу" data-toc-modified-id="Выводы-по-шагу-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Выводы по шагу</a></span></li></ul></li><li><span><a href="#Этап-5.-Проверка-гипотез" data-toc-modified-id="Этап-5.-Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Этап 5. Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные." data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.</a></span></li></ul></li><li><span><a href="#Этап-6.-Заключение-и-выводы" data-toc-modified-id="Этап-6.-Заключение-и-выводы-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Этап 6. Заключение и выводы</a></span></li></ul></div>

# %% [markdown]
# ## Этап 1. Откроем библиотеки, загрузка данных и первичное изучение данных

# %% [markdown]
# ### Загрузим библиотеки

# %% [markdown]
#  Файл содержит информацию о 16715 играх. Согласно документации к данным:
# Name — название игры
# Platform — платформа
# - Year_of_Release — год выпускаGenre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board).
# Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %%
# импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
from IPython.display import display_html 
import seaborn as sns

# %% [markdown]
# ### Загрузим датафрейм и проведем первичный его анализ

# %%
games = pd.read_csv('/datasets/games.csv')

# %%
display(games.head(10))
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# Посмотрели на данные, познакомились с ними, сразу увидели много пропусков.

# %% [markdown]
# ### Изучим информацию

# %%
display(games.describe())
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# Есть ячейки, которые записаны не в чисовом формате

# %%
display(games.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# - Тип object имеют ячейки: Name, Platform , Genre, User_Score, Rating.
#   Исходя из данных датафрейма, можно сделать вывод, что для столбца User_Score тип данных надо будет заменить на float
# - Наблюдаются пропуски в данных. На следующем этапе рассмотрим более внимательно ситуацмю с пропусками и решим, как будем с нимим поступать

# %% [markdown]
# ### Посмотрим на пропуски внимательнее

# %%
empty_values=games.isnull().sum()
print(empty_values)
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# Посмотрим на доли пропусков

# %%
empty_values/games.shape[0]*100
# Out:
# Name                0.011965
# Platform            0.000000
# Year_of_Release     1.609333
# Genre               0.011965
# NA_sales            0.000000
# EU_sales            0.000000
# JP_sales            0.000000
# Other_sales         0.000000
# Critic_Score       51.319174
# User_Score         40.089740
# Rating             40.478612
# dtype: float64

# %% [markdown]
# Больше половины игр не имеют оценки критиков, рейтинг от пользователе отстутствует у 40% и  40.7% - без возрастного рейтинга

# %% [markdown]
# ### Проверим датафрейм на наличие дубликатов

# %%
games.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Полных дубликатов ячеек не обнаружено

# %% [markdown]
# Поищем неполные дубликаты.

# %%
duplicates = games[games.duplicated(subset=['Name', 'Platform'], keep=False)]
duplicates = duplicates.sort_values(by=['Name', 'Platform'])

display(duplicates)
# Out:
#                               Name Platform  Year_of_Release     Genre  \
# 604                  Madden NFL 13      PS3           2012.0    Sports
# 16230                Madden NFL 13      PS3           2012.0    Sports
# 5972   Need for Speed: Most Wanted       PC           2005.0    Racing
# 11715  Need for Speed: Most Wanted       PC           2012.0    Racing
# 1190   Need for Speed: Most Wanted     X360           2012.0    Racing
# 1591   Need for Speed: Most Wanted     X360           2005.0    Racing
# 1745            Sonic the Hedgehog      PS3           2006.0  Platform
# 4127            Sonic the Hedgehog      PS3              NaN  Platform
# 659                            NaN      GEN           1993.0       NaN
# 14244                          NaN      GEN           1993.0       NaN
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 604        2.11      0.22      0.00         0.23          83.0        5.5
# ...

# %% [markdown]
# Мы не можем принимать решение об удалении информации, потому что не знаем источнкиа дубликатов, возможно, это дополнительные сведения об играх, либо сведения из другого ресурса, 5 строк погоды не сделают, поэтому принято решение их оставить

# %% [markdown]
# ### Построим гистограмму для каждого столбца

# %%
games.hist(figsize=(20,20));

# %% [markdown]
# Отобразились только числовые ячейки (а мы форматы еще не меняли, ну ладно).
# Что можно отметить по гистограммам:
# - пик релизов пришелся на 2010 год (если судить по гистограмме)
# - ни одна игра не получила 100% одобрение от критиков

# %% [markdown]
# ### Выводы по этапу

# %% [markdown]
# - 1) В данном этапе мы загрузили необходимые для работы бибилиотеки
# - 2) Посмотрели на первичные данные. Выявили столбцы, по которым наблюдаются пропуски данных
# - 3) Определили, что полных дубликатов строк не обнаружено
# - 3) Выявили столбцы, в которых надо попроавить формат ячеек
# - 4) Построили первичную гистограмму по данным из датафрейма
# - 5) Несоответствующий регистр у столбцов

# %% [markdown]
# ## Этап 2. Предобработка данных

# %% [markdown]
# ### Поправим регистр столбцов.
# Начнем с внешнего оформления таблицы.

# %%
games.columns = [x.lower() for x in games.columns.values]
games.columns.tolist()
# Out:
# ['name',
#  'platform',
#  'year_of_release',
#  'genre',
#  'na_sales',
#  'eu_sales',
#  'jp_sales',
#  'other_sales',
#  'critic_score',
#  'user_score',
#  'rating']

# %% [markdown]
# ### Преобразуем типы данных в столбцах

# %%
games['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# Попадаются nan и tbd. NaN - мы не будем преобразовывать, так как выставление какого-либо числа приведет к изменению среднего рейтинга при подсчете статистических показателей.
# Акроним TBD (To Be Determined) используется в разных отраслях бизнеса для обозначения статуса проектов. "Это будет определено, но позже". Другими словами "Не определено", поэтому заменяем на NaN.

# %%
games.loc[games['user_score'] == 'tbd', 'user_score'] = float('nan')

# %%
games['user_score'] = games['user_score'].astype('float64')

# %%
print(games.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# ### Работа с пропусками

# %% [markdown]
# Пропуске обнаружены в столбцах 'name' 'year_of_release' 'genre'

# %% [markdown]
# #### Удалим пропуски в 'name'

# %%
games[games['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08           NaN         NaN    NaN
# 14244         0.00           NaN         NaN    NaN

# %% [markdown]
# Это те же 2 строки, в которых нет жанра, в целом, в них очень мало данных, никакой исследовательской ценности. Предлагается удалить их.

# %%
games = games.dropna(subset=['name']).reset_index(drop=True)

# %%
games[games['name'].isna()]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating]
# Index: []

# %% [markdown]
# Доля пропусков в 'year_of_release' составляет 1.609333%. Предлагается удалить эти строки.

# %% [markdown]
# #### Удалим пропуски в 'year_of_release'

# %%
games = games.dropna(subset=['year_of_release']).reset_index(drop=True)

# %%
games['year_of_release'].unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000., 1995., 1991., 1981., 1987., 1980.,
#        1983.])

# %%
display(games.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# Я решила удалить строки с пропусками в 'year_of_release' потому что их всего 1,69% и на обшую оценку они не повлияют.

# %% [markdown]
# ### Коррекция данных по рейтингу ('rating')

# %% [markdown]
# Достаточно много пропусков обнаружено в столбцах с рейтингом. Это связано с тем, что не все игры оказываются достаточно коммерчески успешными и даже не доходят до этапа получения возрастного ограничения. Игры без рейтинга мы не удалим, потому что удаление этих строк значительно повлияет на выводы, так как таких строк с пропсуками больше 40%, мы просто оставим их такими какие они есть.

# %% [markdown]
# ESRB означает Совет по рейтингу развлекательного программного обеспечения. Это организация, которая присваивает рейтинги видеоиграм в Северной и Центральной Америке.
#
# - E - Все
# - Е 10+ – Все в возрасте 10+
# - T - подросток
# - M – Зрелые (17+)
# - A – Взрослый (только 18+)
# - RP - Ожидается рейтинг
# - RP (вероятно для взрослых 17+) – Оценка ожидается, но контент, скорее всего, предназначен для людей  старше 17 лет.

# %% [markdown]
# ### Добавление дополнительного столбца по суммарным продажам по всем регионам

# %%
# Посчитайте количество продаж во всех регионах и запишите в отдельный столбец
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']
games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# ...

# %% [markdown]
# ### Посмотрим, что за игры

# %%
games['name'].unique()
display(games.head(20))
# Out:
#                                             name platform  year_of_release  \
# 0                                     Wii Sports      Wii           2006.0
# 1                              Super Mario Bros.      NES           1985.0
# 2                                 Mario Kart Wii      Wii           2008.0
# 3                              Wii Sports Resort      Wii           2009.0
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                         Tetris       GB           1989.0
# 6                          New Super Mario Bros.       DS           2006.0
# 7                                       Wii Play      Wii           2006.0
# 8                      New Super Mario Bros. Wii      Wii           2009.0
# 9                                      Duck Hunt      NES           1984.0
# 10                                    Nintendogs       DS           2005.0
# ...

# %% [markdown]
# ### Выводы по шагу
# На этом этапе мы постарались привести данные в понятный вид, поправили наименования столбцов, изменили типы данных, где это требовалось и поработали с пропусками.
#
# Вместо 16715 строк, стало теперь 16444. Принято решение не трогать столбцы 'critic_score' 'user_score' 'rating', потому что для их заполнения требуется уже участие человека, поэтому отсутствие данные - для нас это тоже сигнал. Столбец 'rating' не трогали еще по той причине, что в нем отсутствует слишком много данных и их удаление значимо повлияет на конечный результат проекта. Добавили столбец 'total_sales'. Еще принято решение не удалять 5 неполных дубликатов.

# %% [markdown]
# ## Этап 3. Ислледовательский анализ данных

# %% [markdown]
# ### Распределение игр по годам релиза
#
# На данном этапе посмотрим, сколько игр выпускалась во все годы

# %%
plt.figure(figsize=(15,5))
plt.plot(games.groupby('year_of_release')['name'].count(), label='Релизы', color='pink')
plt.title('Динамика выхода игр за период с 1980 по 2016 гг')
plt.legend('релиз')
plt.xlabel('Год выпуска')
plt.ylabel('Количество релизов')
plt.grid()
plt.show()

# %% [markdown]
# #### Рассмотрим как менялись продажи по платформам

# %%
sales_by_year=games.groupby('year_of_release')['name'].count()
display(sales_by_year.describe())
display(sales_by_year)
# Out:
# count      37.000000
# mean      444.432432
# std       451.604334
# min         9.000000
# 25%        36.000000
# 50%       338.000000
# 75%       762.000000
# max      1427.000000
# Name: name, dtype: float64
# year_of_release
# 1980.0       9
# 1981.0      46
# 1982.0      36
# 1983.0      17
# 1984.0      14
# 1985.0      14
# 1986.0      21
# 1987.0      16
# 1988.0      15
# 1989.0      17
# 1990.0      16
# 1991.0      41
# 1992.0      43
# 1993.0      60
# 1994.0     121
# 1995.0     219
# 1996.0     263
# 1997.0     289
# 1998.0     379
# 1999.0     338
# 2000.0     350
# 2001.0     482
# 2002.0     829
# 2003.0     775
# 2004.0     762
# 2005.0     939
# 2006.0    1006
# 2007.0    1197
# 2008.0    1427
# 2009.0    1426
# 2010.0    1255
# 2011.0    1136
# 2012.0     653
# 2013.0     544
# 2014.0     581
# 2015.0     606
# 2016.0     502
# Name: name, dtype: int64

# %% [markdown]
# Построим столбчатую диаграмму для визуальной оценки продаж игр по годам

# %%
plt.figure(figsize=(12, 6))
plt.bar(sales_by_year.index, sales_by_year.values, color='skyblue')

plt.title('Количество выпущенных игр по годам', fontsize=14)
plt.xlabel('Год выпуска', fontsize=12)
plt.ylabel('Количество игр', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# График повторяет картинку  "Динамика выхода игр за период с 1980 по 2016 гг", но здесь каждый столбик показывает количество продаж игр и мы точно видим что с 2012 года продажи упали и держаться на уровне 500-650 игр в год

# %% [markdown]
# Активный рост числа релизов наблюдается с 2004-2005 гг, своего пика он достиг примерно в 2007-2008 гг.
#
# Можно выделить "вехи" в игровой индустрии: первая веха - 1993, наблюдается резкий скачок (в 2 раза) релизов. Далее второй скачок случился в 2002 году, потом видим зенит игровой индустрии в 2008 году. после чего - резкий спад без какого-либо плато. Возможно, на спад повлиял мировой финансовый кризис, пользователям было уже совсем не до игр. Еще обратим внимание на резкий упадок в 2012 году (почти в 2 раза). Поэтому предлагается анализировать последние 4 года в следующих заданиях.
#
# Мы проводим не ретроспективу, а анализ для будущих продаж, изменение технологий, смена поколений пользователей приводят нас к этому же выводу, что все 37 лет можно не анализировать.

# %% [markdown]
# Посмотрим статистику по релизам игр в предложенный рассматриваемый период. Для подтверждение правильности выбор указанного периода с 2012 года

# %%
sales_by_year_2 = games[games['year_of_release'] > 2012]
sales_by_year_2 = sales_by_year_2.groupby('year_of_release')['name'].count().reset_index()

sales_by_year_2.columns = ['year', 'number_of_games']
print(sales_by_year_2['number_of_games'].describe())
# Out:
# count      4.000000
# mean     558.250000
# std       45.331189
# min      502.000000
# 25%      533.500000
# 50%      562.500000
# 75%      587.250000
# max      606.000000
# Name: number_of_games, dtype: float64

# %% [markdown]
# Стандартное отклонение небольшое относительно, а медиана недалека от среднего значения, можно говорить о том, что это некая тенденция.

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.

# %%
plt.figure(figsize=(15,5))
plt.plot(games.groupby('year_of_release')['platform'].count(), label='Релизы', color='red')
plt.legend('платформа')
plt.xlabel('Год выпуска')
plt.ylabel('Продажи по платформам')
plt.grid()
plt.show()

# %% [markdown]
# График повторяется, чтобы напомнить картинку.

# %% [markdown]
# #### Визуализируем продажи по платформам

# %%
sales_by_platform_year = games.groupby(['year_of_release', 'platform'])['total_sales'].sum().reset_index()

# повернем таблицу чтобы построить график
sales_by_platform_year_piv = sales_by_platform_year.pivot(index='year_of_release', columns='platform', values='total_sales')
display(sales_by_platform_year_piv.tail(20))
# Out:
# platform         2600  3DO    3DS    DC      DS     GB    GBA     GC  GEN  GG  \
# year_of_release
# 1997.0            NaN  NaN    NaN   NaN     NaN   6.37    NaN    NaN  NaN NaN
# 1998.0            NaN  NaN    NaN  3.38     NaN  26.90    NaN    NaN  NaN NaN
# 1999.0            NaN  NaN    NaN  5.16     NaN  38.00    NaN    NaN  NaN NaN
# 2000.0            NaN  NaN    NaN  5.99     NaN  19.76   0.07    NaN  NaN NaN
# 2001.0            NaN  NaN    NaN  1.07     NaN   9.24  61.53  26.34  NaN NaN
# 2002.0            NaN  NaN    NaN  0.29     NaN    NaN  74.16  51.81  NaN NaN
# 2003.0            NaN  NaN    NaN   NaN     NaN    NaN  56.67  50.61  NaN NaN
# 2004.0            NaN  NaN    NaN   NaN   17.27    NaN  77.91  28.82  NaN NaN
# 2005.0            NaN  NaN    NaN   NaN  130.14    NaN  33.86  27.62  NaN NaN
# 2006.0            NaN  NaN    NaN   NaN  119.81    NaN   5.28  11.26  NaN NaN
# 2007.0            NaN  NaN    NaN  0.02  146.94    NaN   3.40   0.27  NaN NaN
# ...

# %% [markdown]
# #### Построим график по всем платформам.

# %%
# Построение графика
sales_by_platform_year_piv.plot(kind='line', marker='o', figsize=(20, 10))

plt.title('Изменение общих продаж (total_sales) по платформам и годам')
plt.xlabel('Год')
plt.ylabel('Общие продажи (total_sales)')
plt.grid(True)
plt.legend(title='Платформа')

plt.show()

# %% [markdown]
# Действительно,наблюдается активный рост, а затем угасание каждой платформы. За последние 10 лет я играла только в 2 игры: симс и нэнси дрю. Поэтому думала, что PS3,3,4- это всё одна платформа, а это, буквально, версия платформы. Как с теми же айфонами.

# %% [markdown]
# Рассмотрим топ платформ по продажам

# %%
total_sales_by_platform = games.groupby('platform')['total_sales'].sum().reset_index()

print(total_sales_by_platform.sort_values('total_sales', ascending=False).head(10))
# Out:
#    platform  total_sales
# 16      PS2      1233.56
# 28     X360       961.24
# 17      PS3       931.34
# 26      Wii       891.18
# 4        DS       802.78
# 15       PS       727.58
# 18      PS4       314.14
# 6       GBA       312.88
# 19      PSP       289.53
# 2       3DS       257.81

# %% [markdown]
# #### Визуализируем полученные цифры

# %%
selected_platforms = ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS', 'PS4', 'GBA', 'PSP', '3DS']
filtered_games = games[games['platform'].isin(selected_platforms)]

# Группируем по году и платформе, суммируем total_sales
sales_by_year_platform = filtered_games.groupby(['year_of_release', 'platform'])['total_sales'].sum().unstack()

sales_by_year_platform.plot(kind='bar', stacked=True, figsize=(14, 8), colormap='viridis')

#подписи
plt.title('Распределение продаж по годам для выбранных платформ', fontsize=16)
plt.xlabel('Год выпуска', fontsize=14)
plt.ylabel('Общие продажи (в миллионах)', fontsize=14)
plt.legend(title='Платформа', bbox_to_anchor=(1.05, 1), loc='upper left')  # Легенда справа
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# Этот график не в полной мере отражает то, что мы бы хотели увидеть. Но он точно показывает вклад каждой платформы из нашего топ-10 в продажи игр.

# %% [markdown]
# #### График ниже покажет как раз продажи по интересующим нам платформам, просмотрим их динамику на исторической арене, мы их выявили несколько шагов назад это 'PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS', 'PS4', 'GBA', 'PSP', '3DS'

# %%
# Фильтруем данные по указанным платформам
selected_platforms = ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS', 'PS4', 'GBA', 'PSP', '3DS']
filtered_games = games[games['platform'].isin(selected_platforms)]

# Группируем по году и платформе, суммируем total_sales
sales_by_year_platform = filtered_games.groupby(['year_of_release', 'platform'])['total_sales'].sum().unstack()

# Построение линейного графика
plt.figure(figsize=(14, 8))  # Размер графика
for platform in sales_by_year_platform.columns:
    plt.plot(sales_by_year_platform.index, sales_by_year_platform[platform], marker='o', label=platform)

# Добавляем подписи
plt.title('Продажи по годам для каждой платформы (топ-10)', fontsize=16)
plt.xlabel('Год выпуска', fontsize=14)
plt.ylabel('Общие продажи (в миллионах)', fontsize=14)
plt.legend(title='Платформа', bbox_to_anchor=(1.05, 1), loc='upper left')  # Легенда справа
plt.grid(linestyle='--', alpha=0.7)

# %% [markdown]
# #### Посмотрим на первый год продаж у каждой платформы (первый год после появления платформы на рынке)

# %%
max_sales_games = games.groupby('platform').agg(
    max_total_sales=('total_sales', 'max'), 
    year_of_release=('year_of_release', 'min')  # Год выпуска (первый в группе)
).reset_index()

display(max_sales_games.sort_values('max_total_sales', ascending=False))
# Out:
#    platform  max_total_sales  year_of_release
# 26      Wii            82.54           2006.0
# 11      NES            40.24           1983.0
# 5        GB            31.38           1988.0
# 4        DS            29.80           1985.0
# 28     X360            21.82           2005.0
# 17      PS3            21.05           2006.0
# 16      PS2            20.81           2000.0
# 23     SNES            20.62           1990.0
# 6       GBA            15.84           2000.0
# 18      PS4            14.63           2013.0
# 2       3DS            14.60           2011.0
# 10      N64            11.90           1996.0
# 15       PS            10.95           1994.0
# 29       XB             8.48           2000.0
# 13       PC             8.01           1985.0
# 0      2600             7.81           1980.0
# 19      PSP             7.68           2004.0
# 30     XOne             7.39           2013.0
# 27     WiiU             7.09           2012.0
# ...

# %% [markdown]
# #### Посчитаем все года, когда происходили продажи для самых популярных платформ, чтобы определить срок жизни платформы в среднем.

# %%
# Группируем по платформе и считаем количество уникальных годов
unique_years_per_platform = games.groupby('platform')['year_of_release'].nunique().reset_index()

display(unique_years_per_platform.describe())
# Out:
#        year_of_release
# count        31.000000
# mean          7.677419
# std           5.081910
# min           1.000000
# 25%           4.000000
# 50%           7.000000
# 75%          11.000000
# max          26.000000

# %% [markdown]
# Все эти платформы в рамках дальнейшего исследования нам неинтересны уже.
# **Но мы можем ответить на вопрос о длительности жизни каждой платформы - это где-то от 5 до 7,6 лет**

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# Не учитывайте в работе данные за предыдущие годы.

# %% [markdown]
# #### Актуальный период для исследования

# %% [markdown]
# В 3.1 мы уже решили исследовать далее годы с 2012 по 2016, так как они лучше будут отображать спрос на в=игры современных пользователей
# - 2012.0  -   653
# - 2013.0  -   544
# - 2014.0  -   581
# - 2015.0  -   606
# - 2016.0  -   502

# %% [markdown]
# #### Если до этого мы выявляли топ 10 по продажам, то тут посмотрим на динамику продаж платформ за конкретный период с 2012 по 2016 гг.

# %%
# Фильтруем данные по годам с 2012 по 2016
filtered_games = games[(games['year_of_release'] >= 2012) & (games['year_of_release'] <= 2016)]

# Группируем по году и платформе, суммируем total_sales
sales_by_year_platform = filtered_games.groupby(['year_of_release', 'platform'])['total_sales'].sum().unstack()
display(sales_by_year_platform)
display(sales_by_year_platform.describe())
# Построение графика
plt.figure(figsize=(12, 6))  # Размер графика
for platform in sales_by_year_platform.columns:
    plt.plot(sales_by_year_platform.index, sales_by_year_platform[platform], marker='o', label=platform)

# Добавляем подписи
plt.title('Динамика продаж игр каждой платформы в года с 2012–2016 ', fontsize=16)
plt.xlabel('Год выпуска', fontsize=14)
plt.ylabel('Общие продажи', fontsize=14)
plt.legend(title='Платформа', bbox_to_anchor=(1.05, 1), loc='upper left')  # Легенда справа
plt.grid(linestyle='--', alpha=0.7)  # Сетка

# Показать график
plt.tight_layout()
plt.show()
# Out:
# platform           3DS     DS     PC     PS3     PS4   PSP    PSV    Wii  \
# year_of_release
# 2012.0           51.36  11.01  23.22  107.36     NaN  7.69  16.19  21.71
# 2013.0           56.57   1.54  12.38  113.25   25.99  3.14  10.59   8.59
# 2014.0           43.76    NaN  13.28   47.76  100.00  0.24  11.90   3.75
# 2015.0           27.78    NaN   8.52   16.82  118.90  0.12   6.25   1.14
# 2016.0           15.14    NaN   5.25    3.60   69.25   NaN   4.25   0.18
#
# platform          WiiU   X360   XOne
# year_of_release
# 2012.0           17.56  99.74    NaN
# 2013.0           21.65  88.58  18.96
# 2014.0           22.03  34.74  54.07
# 2015.0           16.35  11.96  60.14
# 2016.0            4.60   1.52  26.15
# platform        3DS         DS         PC         PS3         PS4       PSP  \
# count      5.000000   2.000000   5.000000    5.000000    4.000000  4.000000
# mean      38.922000   6.275000  12.530000   57.758000   78.535000  2.797500
# ...

# %% [markdown]
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# Этот график отличается от графика топ-10 и это нормально. Сейчас на данном графике мы наблюдаем, что нарпавление игр все равно находится в небольшом упадке, многие платформы прошли зенит своей жизни. Самой активной по продажам является платформа PS-4, на втором месте XOne.
# Продажи падают. Исходя из всех данных, я бы рекомендовала обратить внимание на PS-4, XOne и 3DS (но ей уже 5 лет, срок ее жизни истекает) и ждать выхода новых платформ.

# %% [markdown]
# #### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
games_from_top_platforms = filtered_games.query('platform in ["PS4", "3DS", "XOne"] and year_of_release >= 2012')

# %%
display(games_from_top_platforms.head(5))
# Out:
#                                          name platform  year_of_release  \
# 31                  Call of Duty: Black Ops 3      PS4           2015.0
# 33                        Pokemon X/Pokemon Y      3DS           2013.0
# 42                         Grand Theft Auto V      PS4           2014.0
# 47  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS           2014.0
# 62                    New Super Mario Bros. 2      3DS           2012.0
#
#            genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 31       Shooter      6.03      5.86      0.36         2.38           NaN
# 33  Role-Playing      5.28      4.19      4.35         0.78           NaN
# 42        Action      3.96      6.31      0.38         1.97          97.0
# 47  Role-Playing      4.35      3.49      3.10         0.74           NaN
# 62      Platform      3.66      3.14      2.47         0.63          78.0
#
#     user_score rating  total_sales
# 31         NaN    NaN        14.63
# ...

# %% [markdown]
# Выделили топ-3 платформы и посмотрим на них в период с 2012 по 2016

# %% [markdown]
# ##### Строим boxplots для наших платформ по продажам игр

# %%
top_platforms = ['PS4', 'XOne', '3DS']
(games_from_top_platforms.query('platform in @top_platforms')[['platform', 'name', 'total_sales']]
 .boxplot(column='total_sales', by='platform', figsize=(10,10))
)
plt.ylabel('Количество проданных копий, млн')
plt.title('Диаграммы размаха по продажам на данных платформах')
plt.ylim(0, 4)
plt.show()

# %% [markdown]
# Скорее всего эти выбросы - это какие-то суперкрутые и залетевшие игры, больше всег таких залетевших игр у PS-4, конечно, это подтверждено данным "ящиком с усами".

# %% [markdown]
# Добавим график по всем платформам с 2012 г

# %%
all_platforms = ['PS3', 'X360', 'PS4', '3DS', 'DS', 'XOne', 'WiiU', 'Wii', 'PC','PSV', 'PSP']
(filtered_games.query('platform in @all_platforms')[['platform', 'name', 'total_sales']]
 .boxplot(column='total_sales', by='platform', figsize=(15,10))
)
plt.ylabel('Количество проданных копий, млн')
plt.title('Диаграммы размаха по продажам для всех платформ с 2012 по 2016 гг')
plt.ylim(0, 4)
plt.show()

# %% [markdown]
# Меньше всего игр-легенд выходило на платформах DS и PSP

# %% [markdown]
# ### Влияние на продажи внутри одной популярной платформы отзывов пользователей и критиков

# %%
# Убираем строки, где user_score отсутствует
filtered_data = games_from_top_platforms.dropna(subset=['user_score'])
display(filtered_data)
# Out:
#                                  name platform  year_of_release       genre  \
# 42                 Grand Theft Auto V      PS4           2014.0      Action
# 62            New Super Mario Bros. 2      3DS           2012.0    Platform
# 73          Animal Crossing: New Leaf      3DS           2012.0  Simulation
# 77                            FIFA 16      PS4           2015.0      Sports
# 92     Call of Duty: Advanced Warfare      PS4           2014.0     Shooter
# ...                               ...      ...              ...         ...
# 16273     Assassin's Creed Chronicles     XOne           2016.0      Action
# 16326     Saints Row: Gat out of Hell     XOne           2015.0      Action
# 16359        Sébastien Loeb Rally Evo     XOne           2016.0      Racing
# 16372               Rugby Challenge 3     XOne           2016.0      Sports
# 16389                Prison Architect     XOne           2016.0      Action
#
# ...

# %% [markdown]
# #### Взаимосвязи между отзывами и продажами для PS4

# %%
# Фильтруем данные для платформы PS4
ps4_data = games_from_top_platforms[games_from_top_platforms['platform'] == 'PS4']
display(ps4_data.head(10))
display(ps4_data.describe())

# Настройка стиля
sns.set(style="whitegrid")

# Диаграмма рассеяния: critic_score and total_sales
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x='critic_score', y='total_sales', data=ps4_data)
plt.title('Влияние отзывов критиков Продажи (PS4)')
plt.xlabel('Оценка критиков')
plt.ylabel('Продажи, млн')

# Диаграмма рассеяния: user_score and total_sales
plt.subplot(1, 2, 2)
sns.scatterplot(x='user_score', y='total_sales', data=ps4_data)
plt.title('Влияние отзывов пользователей на Продажи (PS4)')
plt.xlabel('Оценка пользователей')
plt.ylabel('Продажи, млн')

plt.tight_layout()
plt.show()

# Диаграмма рассеяния: user_score and critic_score
plt.subplot(1, 3, 3)
sns.scatterplot(x='critic_score', y='user_score', data=ps4_data)
plt.title('Отзывы критиков vs Отзывы пользователей (PS4)')
plt.xlabel('Оценка критиков')
plt.ylabel('Оценка пользователей')

plt.tight_layout()
plt.show()


corr_critic = ps4_data['critic_score'].corr(ps4_data['total_sales']) #корреляция между отзывами критиков и продажами
corr_user = ps4_data['user_score'].corr(ps4_data['total_sales'])#корреляция между отзывами пользователей и продажами
corr_critic_user = ps4_data['critic_score'].corr(ps4_data['user_score'])#корреляция между отзывами критиков и отзывами пользователей

print(f"Корреляция между отзывами критиков и продажами: {corr_critic:.2f}")
print(f"Корреляция между отзывами пользователей и продажами: {corr_user:.2f}")
print(f"Корреляция между отзывами критиков и отзывами пользователей: {corr_critic_user:.2f}")
# Out:
#                                name platform  year_of_release         genre  \
# 31        Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 42               Grand Theft Auto V      PS4           2014.0        Action
# 77                          FIFA 16      PS4           2015.0        Sports
# 87     Star Wars Battlefront (2015)      PS4           2015.0       Shooter
# 92   Call of Duty: Advanced Warfare      PS4           2014.0       Shooter
# 94                          FIFA 17      PS4           2016.0        Sports
# 105                       Fallout 4      PS4           2015.0  Role-Playing
# 143                         FIFA 15      PS4           2014.0        Sports
# 154                         Destiny      PS4           2014.0       Shooter
# 171      Uncharted 4: A Thief's End      PS4           2016.0       Shooter
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %% [markdown]
# Небольшая зависимость между отзывами критиков и продажами присутствует, коэффициент корреляции равен 0,41. Зависимости между продажами и отзывами пользователей нет.
# Кроме того, хочется отметить, что релизов игр дейтсвительно очень много, и не многгие из них заслуживают того, чтобы получить хоть какую-то оценку от критиков, а потом от пользователей. Обычно, критики выставляют свои рейтинги уть раньше пользователей, таким образом они способны влиять на формирование спроса и равитие индустрии. Пользователи зачастую ставят оценки уже постфактум, когда ажиотаж.
#
# А вот пользователи сходятся во мнении с критиками, не всегда, но тенденция есть.

# %% [markdown]
# #### Взаимосвязи между отзывами и продажами для 3DS

# %%
# Фильтруем данные для платформы 3DS
three_ds_data = games_from_top_platforms[games_from_top_platforms['platform'] == '3DS']
display(three_ds_data.head(10))

display(ps4_data.describe())

# Настройка стиля
sns.set(style="whitegrid")

# Диаграмма рассеяния: critic_score and total_sales
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x='critic_score', y='total_sales', data=three_ds_data)
plt.title('Влияние отзывов критиков Продажи (3DS)')
plt.xlabel('Оценка критиков')
plt.ylabel('Продажи, млн')

# Диаграмма рассеяния: user_score and total_sales
plt.subplot(1, 2, 2)
sns.scatterplot(x='user_score', y='total_sales', data=three_ds_data)
plt.title('Влияние отзывов пользователей на Продажи (3DS)')
plt.xlabel('Оценка пользователей')
plt.ylabel('Продажи, млн')

plt.tight_layout()
plt.show()

# Диаграмма рассеяния: user_score and critic_score
plt.subplot(1, 3, 3)
sns.scatterplot(x='critic_score', y='user_score', data=three_ds_data)
plt.title('Отзывы критиков vs Отзывы пользователей (3DS)')
plt.xlabel('Оценка критиков')
plt.ylabel('Оценка пользователей')

plt.tight_layout()
plt.show()


corr_critic = three_ds_data['critic_score'].corr(three_ds_data['total_sales']) #корреляция между отзывами критиков и продажами
corr_user = three_ds_data['user_score'].corr(three_ds_data['total_sales'])#корреляция между отзывами пользователей и продажами
corr_critic_user = three_ds_data['critic_score'].corr(three_ds_data['user_score'])#корреляция между отзывами критиков и отзывами пользователей

print(f"Корреляция между отзывами критиков и продажами: {corr_critic:.2f}")
print(f"Корреляция между отзывами пользователей и продажами: {corr_user:.2f}")
print(f"Корреляция между отзывами критиков и отзывами пользователей: {corr_critic_user:.2f}")
# Out:
#                                           name platform  year_of_release  \
# 33                         Pokemon X/Pokemon Y      3DS           2013.0
# 47   Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS           2014.0
# 62                     New Super Mario Bros. 2      3DS           2012.0
# 73                   Animal Crossing: New Leaf      3DS           2012.0
# 96         Super Smash Bros. for Wii U and 3DS      3DS           2014.0
# 108                           Pokemon Sun/Moon      3DS           2016.0
# 183                             Tomodachi Life      3DS           2013.0
# 234                 Luigi's Mansion: Dark Moon      3DS           2013.0
# 311                  Monster Hunter 4 Ultimate      3DS           2014.0
# 383                           Monster Hunter 4      3DS           2013.0
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 33   Role-Playing      5.28      4.19      4.35         0.78           NaN
# ...

# %% [markdown]
# Для 3DS наблюдается слабая зависимость между отзывами критиков и продажами, меньше только между отзывами пользователей и продажами, но в выводе для PS4 я более подробно рассказала о причинах этого яаления и оно актуально для 3DS.
# Но мы точно можем утверждать, что пользователи сходятся с критиками касательно оценок для игр, это подтверждается достаточно умеренной корреляцией - 0,72

# %% [markdown]
# #### Взаимосвязи между отзывами и продажами для XOne

# %%
# Фильтруем данные для платформы 3DS
xone_data = games_from_top_platforms[games_from_top_platforms['platform'] == 'XOne']
display(xone_data.head(10))

display(xone_data.describe())

# Настройка стиля
sns.set(style="whitegrid")

# Диаграмма рассеяния: critic_score and total_sales
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(x='critic_score', y='total_sales', data=xone_data)
plt.title('Влияние отзывов критиков Продажи (XOne)')
plt.xlabel('Оценка критиков')
plt.ylabel('Продажи, млн')

# Диаграмма рассеяния: user_score and total_sales
plt.subplot(1, 2, 2)
sns.scatterplot(x='user_score', y='total_sales', data=xone_data)
plt.title('Влияние отзывов пользователей на Продажи (XOne)')
plt.xlabel('Оценка пользователей')
plt.ylabel('Продажи, млн')

plt.tight_layout()
plt.show()

# Диаграмма рассеяния: user_score and critic_score
plt.subplot(1, 3, 3)
sns.scatterplot(x='critic_score', y='user_score', data=xone_data)
plt.title('Отзывы критиков и Отзывы пользователей (XOne)')
plt.xlabel('Оценка критиков')
plt.ylabel('Оценка пользователей')

plt.tight_layout()
plt.show()


corr_critic = xone_data['critic_score'].corr(xone_data['total_sales']) #корреляция между отзывами критиков и продажами
corr_user = xone_data['user_score'].corr(xone_data['total_sales'])#корреляция между отзывами пользователей и продажами
corr_critic_user = xone_data['critic_score'].corr(xone_data['user_score'])#корреляция между отзывами критиков и отзывами пользователей

print(f"Корреляция между отзывами критиков и продажами: {corr_critic:.2f}")
print(f"Корреляция между отзывами пользователей и продажами: {corr_user:.2f}")
print(f"Корреляция между отзывами критиков и отзывами пользователей: {corr_critic_user:.2f}")
# Out:
#                                name platform  year_of_release         genre  \
# 99        Call of Duty: Black Ops 3     XOne           2015.0       Shooter
# 165              Grand Theft Auto V     XOne           2014.0        Action
# 179  Call of Duty: Advanced Warfare     XOne           2014.0       Shooter
# 241               Halo 5: Guardians     XOne           2015.0       Shooter
# 269                       Fallout 4     XOne           2015.0  Role-Playing
# 341    Star Wars Battlefront (2015)     XOne           2015.0       Shooter
# 372         Assassin's Creed: Unity     XOne           2014.0        Action
# 396                         Destiny     XOne           2014.0       Shooter
# 411  Gears of War: Ultimate Edition     XOne           2015.0       Shooter
# 415                         FIFA 16     XOne           2015.0        Sports
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %% [markdown]
# Небольшая зависимость между отзывами критиков и продажами присутствует, коэффициент корреляции равен 0,42. Зависимости между продажами и отзывами пользователей нет. Также как и для PS4, есть слабая зависимость между между отзывами критиков и отзывами пользователей.

# %% [markdown]
# #### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Возьмем таблицу с данными с 2012 по 2016 гг

# %%
genre_counts = filtered_games.groupby('genre').agg(
    count=('name', 'size')  # Подсчёт количества игр в каждом жанре
).reset_index()
genre_counts_sorted = genre_counts.sort_values(by='count', ascending=False)

display(genre_counts_sorted)
# Out:
#            genre  count
# 0         Action   1031
# 7   Role-Playing    370
# 1      Adventure    302
# 10        Sports    268
# 8        Shooter    235
# 3           Misc    192
# 6         Racing    115
# 2       Fighting    109
# 4       Platform     85
# 9     Simulation     80
# 11      Strategy     71
# 5         Puzzle     28

# %% [markdown]
# Самым популярным жанром игр является экшен,спортивные игры и игры в жанре 'misc' - это как симс. а вот абстрактные головоломки являются наименее популярным жанром.

# %% [markdown]
# Посмотрим на релизы игр

# %%
genre_year_counts = games_from_top_platforms.groupby(['genre', 'year_of_release']).agg(
    count=('name', 'size')  # Количество игр
).reset_index()

# Создаем сводную таблицу (pivot table)
pivot_table = genre_year_counts.pivot(index='genre', columns='year_of_release', values='count')

# Заполняем пропущенные значения нулями
pivot_table = pivot_table.fillna(0)

# Проверка, есть ли данные для heatmap
if pivot_table.empty:
    print("Нет данных для построения heatmap.")
else:
    display("Таблица количества игр по жанрам и годам:",pivot_table)

    plt.figure(figsize=(10, 6))
    sns.heatmap(pivot_table, annot=True, fmt='g', cmap='viridis', linewidths=0.5)
    plt.title('Количество игр по жанрам и годам')
    plt.xlabel('Год выпуска')
    plt.ylabel('Жанр')
    plt.show()
# Out:
# 'Таблица количества игр по жанрам и годам:'
# year_of_release  2012.0  2013.0  2014.0  2015.0  2016.0
# genre
# Action             40.0    35.0    78.0   118.0   114.0
# Adventure           6.0     6.0    21.0    20.0    22.0
# Fighting            2.0     5.0     3.0    14.0    10.0
# Misc                9.0    15.0    18.0    19.0    19.0
# Platform            4.0    11.0     5.0     6.0    10.0
# Puzzle              4.0     2.0     3.0     5.0     0.0
# Racing              1.0     3.0     7.0    11.0    18.0
# Role-Playing       17.0    21.0    30.0    47.0    29.0
# Shooter             1.0     6.0    17.0    22.0    35.0
# Simulation          5.0     6.0     4.0     6.0     9.0
# Sports              4.0    11.0    25.0    29.0    27.0
# Strategy            0.0     5.0     5.0     6.0     4.0

# %%
# Для расчета статистики повернем таблицу

pivot_table_2 = genre_year_counts.pivot(index='year_of_release', columns='genre', values='count')
display(pivot_table_2.describe())
# Out:
# genre      Action  Adventure   Fighting       Misc   Platform    Puzzle  \
# count    5.000000   5.000000   5.000000   5.000000   5.000000  4.000000
# mean    77.000000  15.000000   6.800000  16.000000   7.200000  3.500000
# std     39.319207   8.246211   5.069517   4.242641   3.114482  1.290994
# min     35.000000   6.000000   2.000000   9.000000   4.000000  2.000000
# 25%     40.000000   6.000000   3.000000  15.000000   5.000000  2.750000
# 50%     78.000000  20.000000   5.000000  18.000000   6.000000  3.500000
# 75%    114.000000  21.000000  10.000000  19.000000  10.000000  4.250000
# max    118.000000  22.000000  14.000000  19.000000  11.000000  5.000000
#
# genre    Racing  Role-Playing   Shooter  Simulation     Sports  Strategy
# count   5.00000       5.00000   5.00000    5.000000   5.000000  4.000000
# mean    8.00000      28.80000  16.20000    6.000000  19.200000  5.000000
# std     6.78233      11.54123  13.44247    1.870829  11.054411  0.816497
# ...

# %%
#box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=pivot_table_2)
plt.title('ящик с усами по жанрам игр')
plt.xlabel('жанр')
plt.ylabel('количество игр')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# В последние годы к самым популярным жанрам (топ-3) можно отнести следующие: **Action**,**Role-Playing**, **Sports**, **Adventure**

# %% [markdown]
# ### Выводы по шагу

# %% [markdown]
# Познакомились с продажами игр, оценили примерный срок годности игровой платформы, пришли к выводу, что в дальнейшем будем анализировать данные за 2012-2016 гг. Увидели, что некоторые платформы иногда выпускают "легенды", которые выстреливают.
# Выявили, что внешние факторы, такие как кризис могут влиять на спрос пользователей. Кроме того и смена поколений, а также и развитие технологий влияют на это.
# Еще мы проследили зависимость продаж от оценки критиков и пользователей.
# Определили топ-3 жанра за рассматриваемые 4 года:Action,Role-Playing и Sports

# %% [markdown]
# ## Этап 4. Портрет пользователя каждого региона
# (на период с 2012 по 2016 гг)
# - Определите для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
filtered_games.head()
# Out:
#                           name platform  year_of_release         genre  \
# 16          Grand Theft Auto V      PS3           2013.0        Action
# 23          Grand Theft Auto V     X360           2013.0        Action
# 31   Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 33         Pokemon X/Pokemon Y      3DS           2013.0  Role-Playing
# 34  Call of Duty: Black Ops II      PS3           2012.0       Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38           NaN         NaN
# 33      5.28      4.19      4.35         0.78           NaN         NaN
# 34      4.99      5.73      0.65         2.42          83.0         5.3
#
#    rating  total_sales
# 16      M        21.05
# 23      M        16.27
# 31    NaN        14.63
# ...

# %%
# Группируем по платформе и считаем суммарные продажи для каждого региона
platform_sales = filtered_games.groupby('platform').agg(
    na_sales=('na_sales', 'sum'),
    eu_sales=('eu_sales', 'sum'), 
    jp_sales=('jp_sales', 'sum')   
).reset_index()

# Находим топ-5 платформ для каждого региона
top_na_platforms = platform_sales.nlargest(5, 'na_sales')[['platform', 'na_sales']]
top_eu_platforms = platform_sales.nlargest(5, 'eu_sales')[['platform', 'eu_sales']]
top_jp_platforms = platform_sales.nlargest(5, 'jp_sales')[['platform', 'jp_sales']]

top_platforms = pd.concat([top_na_platforms.reset_index(drop=True),
                           top_eu_platforms.reset_index(drop=True),
                           top_jp_platforms.reset_index(drop=True)], axis=1)
display("Топ-5 платформ по регионам:",top_platforms )
# Out:
# 'Топ-5 платформ по регионам:'
#   platform  na_sales platform  eu_sales platform  jp_sales
# 0     X360    140.05      PS4    141.09      3DS     87.79
# 1      PS4    108.74      PS3    106.86      PS3     35.29
# 2      PS3    103.38     X360     74.52      PSV     21.04
# 3     XOne     93.12     XOne     51.59      PS4     15.96
# 4      3DS     55.31      3DS     42.64     WiiU     13.01

# %% [markdown]
# Построим графики для наглядности

# %%
plt.figure(figsize=(18, 6))

# График для NA
plt.subplot(1, 3, 1)
sns.barplot(x='platform', y='na_sales', data=top_na_platforms, palette='viridis')
plt.title('Топ-5 платформ в NA')
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи, млн')

# График для EU
plt.subplot(1, 3, 2)
sns.barplot(x='platform', y='eu_sales', data=top_eu_platforms, palette='viridis')
plt.title('Топ-5 платформ в EU')
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи, млн')

# График для JP
plt.subplot(1, 3, 3)
sns.barplot(x='platform', y='jp_sales', data=top_jp_platforms, palette='viridis')
plt.title('Топ-5 платформ в JP')
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи, млн')

# Улучшаем расположение графиков
plt.tight_layout()

# %% [markdown]
# Удивительно, но в разных регионах пользователи отдают свое предпочтение разных платформам. Возможно это зависит от производителей, ведь отечественный продукт обычно более распространен в своей стране (если он конкурентный).
# - DS - это Nintendo (Япония), так что высокая популярность нинтендо в Японии объяснима.
# - X360 - это платформа от Microsoft, ее широкое распространение в Северной Америке тоже ожидаемо и очевидно.
# - PS2 - в ЕС выбиватеся из моей стройной гипотезы.
# Здесь еще немаловажный факт, что если x360 и PS - это обычные приставки, которые стоят дома у полльзователей, то нинтендо достаточно мобильна (портативная мини-приставка) и ее пользователи могут брать с собой и играть по дороге на работу и тд. Здесь еще важную роль играет и менталитет

# %% [markdown]
# #### Самые популярные жанры (топ-5). Поясните разницу

# %%
# Группируем по жанру и считаем суммарные продажи для каждого региона
genre_sales = games_from_top_platforms.groupby('genre').agg(
    na_sales=('na_sales', 'sum'),  # Суммарные продажи в NA
    eu_sales=('eu_sales', 'sum'),  # Суммарные продажи в EU
    jp_sales=('jp_sales', 'sum')   # Суммарные продажи в JP
).reset_index()

# Находим топ-5 жанров для каждого региона
top_5_na_genres = genre_sales.nlargest(5, 'na_sales')[['genre', 'na_sales']]
top_5_eu_genres = genre_sales.nlargest(5, 'eu_sales')[['genre', 'eu_sales']]
top_5_jp_genres = genre_sales.nlargest(5, 'jp_sales')[['genre', 'jp_sales']]

# Выводим результаты
display("NA:", top_5_na_genres)
display("EU:", top_5_eu_genres)
display("JP:", top_5_jp_genres)
# Out:
# 'NA:'
#            genre  na_sales
# 8        Shooter     69.52
# 0         Action     67.96
# 7   Role-Playing     38.08
# 10        Sports     36.10
# 4       Platform     10.24
# 'EU:'
#            genre  eu_sales
# 0         Action     64.48
# 8        Shooter     57.02
# 10        Sports     36.36
# 7   Role-Playing     29.76
# 6         Racing     12.17
# 'JP:'
#           genre  jp_sales
# 7  Role-Playing     42.49
# 0        Action     26.46
# 9    Simulation      9.57
# 3          Misc      5.79
# 4      Platform      4.81

# %% [markdown]
# Визуализируем таблицы

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='genre', y='na_sales', data=top_5_na_genres, palette='viridis')
plt.title('Топ 5 жанров по продажам в NA')
plt.xlabel('Жанр')
plt.ylabel('Продажи в NA, млн')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='genre', y='eu_sales', data=top_5_eu_genres, palette='viridis')
plt.title('Топ 5 жанров по продажам в EU')
plt.xlabel('Жанр')
plt.ylabel('Продажи в EU, млн')
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x='genre', y='jp_sales', data=top_5_jp_genres, palette='viridis')
plt.title('Топ 5 жанров по продажам в JP')
plt.xlabel('Жанр')
plt.ylabel('Продажи в JP, млн')
plt.show()

# %% [markdown]
# Жанр экшен дальше второй сторчки не уходит, однако топ-1 у всех трех регионов различный. В Японии предпочитают многопользовательские онлайн игры, в ЕС - экшен, а в Северной Америке - стрелялки.

# %% [markdown]
# #### Влияет ли рейтинг ESRB на продажи в отдельном регионе?
# (за 2012-2016 гг)

# %% [markdown]
# В пункте 2.4 мы описали рейтинги.
# ESRB означает Совет по рейтингу развлекательного программного обеспечения. Это организация, которая присваивает рейтинги видеоиграм в Северной и Центральной Америке.
#
# - E - Все
# - Е 10+ – Все в возрасте 10+
# - T - подросток
# - M – Зрелые (17+)
# - A – Взрослый (только 18+)
# - RP - Ожидается рейтинг
# - RP (вероятно для взрослых 17+) – Оценка ожидается, но контент, скорее всего, предназначен для людей старше 17 лет.

# %% [markdown]
# Посмотрим на рейтинги топ игр. Функция для группировки и поиска топ-5 рейтингов:

# %%
def get_top_5_ratings(df, sales_column, region_name):
    # Группируем по рейтингу и считаем суммарные продажи
    rating_sales = df.groupby('rating').agg(
        sales=(sales_column, 'sum')  # Суммарные продажи
    ).reset_index()

    rating_sales = rating_sales.dropna(subset=['rating'])
    top_5_ratings = rating_sales.nlargest(5, 'sales')[['rating', 'sales']]
    top_5_ratings = top_5_ratings.rename(columns={'sales': f'{sales_column}'})

    return top_5_ratings

# Получаем топ-5 рейтингов для каждого региона
top_5_na_ratings = get_top_5_ratings(games_from_top_platforms, 'na_sales', 'NA')
top_5_jp_ratings = get_top_5_ratings(games_from_top_platforms, 'jp_sales', 'JP')
top_5_eu_ratings = get_top_5_ratings(games_from_top_platforms, 'eu_sales', 'EU')


display("Возрастной рейтинг в NA:", top_5_na_ratings)
display("Возрастной рейтинг  в JP:",top_5_jp_ratings)
display("Возрастной рейтинг  в EU:",top_5_eu_ratings)
# Out:
# 'Возрастной рейтинг в NA:'
#   rating  na_sales
# 2      M     89.07
# 0      E     48.47
# 3      T     30.13
# 1   E10+     26.35
# 'Возрастной рейтинг  в JP:'
#   rating  jp_sales
# 0      E     17.17
# 3      T      9.12
# 2      M      6.91
# 1   E10+      4.59
# 'Возрастной рейтинг  в EU:'
#   rating  eu_sales
# 2      M     82.59
# 0      E     52.66
# 3      T     25.22
# 1   E10+     18.35

# %%
filtered_games.groupby(by='rating').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(kind='bar', color='green');
filtered_games.groupby(by='rating').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(kind='bar', color= 'orange');
filtered_games.groupby(by='rating').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(kind='bar', color='skyblue');

# %% [markdown]
# Можно утверждать, что рейтинг влияет на продажи, потому что самыми популрными играми в итоге становятся те, у которых почти нет возрастных ограничений, такие игры могут привлечь большую аудиторию, потому что подходят всем. Также некоторые игры есть и с высоким рейтингом. Тут важно понимать, что игры должны быть интересны и платежеспособным пользователям.
# В регионах наиболее популярны игры для всех возрастов (они охватывают больше людей), подростков с 13 до 17 лет и зрелых - это 17+.
# - Обычный японский пользователь - это человек в возрасте от 0 и до 25-30, играющий в многопользовательскую игру на нинтендо :)
# - Обычный североамериканский пользователь - это тоже молодой человек,с приставкой x360, предпочитающий стрелялки.
# - Обычный европейский пользователь - это молодой человек, обладатель PS4, играющий в GTA.

# %% [markdown]
# ### Выводы по шагу
#
# Нам удалось составить образы типичных любителей игр для стран Северной Америки, ЕС и Японии. Определили, что возрастной рейтинг тоже вносит вклад в спрос игр.

# %% [markdown]
# ## Этап 5. Проверка гипотез

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# (за период с 2012 по 2016 гг)

# %% [markdown]
# Для проверки данной гипотезы будем испльзовать двухвыборочный t-тест для независимых выборок (stats.ttest_ind).
# Сформулируем гипотезы:
# - **Нулевая гипотеза (H0)**: Средние пользовательские рейтинги платформ Xbox One и PC равны.
# - **Альтернативная гипотеза (H1)**: Средние пользовательские рейтинги платформ Xbox One и PC не равны.

# %%
xbox_one_ratings = filtered_games[(filtered_games['platform'] == 'XOne') & (filtered_games['user_score'] > 0)]['user_score']
pc_ratings = filtered_games[(filtered_games['platform'] == 'PC') & (filtered_games['user_score'] > 0)]['user_score']

alpha = 0.05

results = st.ttest_ind(xbox_one_ratings, pc_ratings)

print(f"p-value:", results.pvalue)


if results.pvalue > 0.05:
    print("Нет оснований отвергнуть нулевую гипотезу. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.")
else:
    print("Отвергаем нулевую гипотезу. Средние пользовательские рейтинги платформ Xbox One и PC не равны.")
# Out:
# p-value: 0.5535080500643661
# Нет оснований отвергнуть нулевую гипотезу. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# (за период с 2012 по 2016 гг)

# %% [markdown]
# Для проверки данной гипотезы будем тоже испльзовать двухвыборочный t-тест для независимых выборок (stats.ttest_ind).
# Сформулируем гипотезы:
# - **Нулевая гипотеза (H0)**: Средние пользовательские рейтинги жанров Action и Sports равны.
# - **Альтернативная гипотеза (H1)**: Средние пользовательские рейтинги жанров Action и Sports различаются.

# %%
action = filtered_games[(filtered_games['genre'] == 'Action') & (filtered_games['user_score'] > 0)]['user_score']
sports = filtered_games[(filtered_games['genre'] == 'Sports') & (filtered_games['user_score'] > 0)]['user_score']
alpha = 0.05

# Проводим двухвыборочный t-тест
result = st.ttest_ind(action, sports)
print('p-value:', result.pvalue)

if result.pvalue > 0.05:
    print("Нет оснований отвергать нулевую гипотезу. Средние пользовательские рейтинги жанров Action и Sports одинаковые.")
else:
    print("Отвергаем нулевую гипотезу. Средние пользовательские рейтинги жанров Action и Sports различаются.")
# Out:
# p-value: 3.7163089460934874e-26
# Отвергаем нулевую гипотезу. Средние пользовательские рейтинги жанров Action и Sports различаются.

# %% [markdown]
# В обоих заданиях я выбрала уровень значимости 5% потому что это значение является общепринятым и широкораспространенным. Это нормальный в меру строгий уровень.

# %% [markdown]
# ## Этап 6. Заключение и выводы

# %% [markdown]
# В рамках данного проекта мы познакомились с игровой индустрией, закрепили знания по подготовке, исследованию данных, а также закрепили знания о проверке гипотез.
# - определили топ платформ по продажам игр: PS2, X360,PS3
# - самый прибыльный жанр за всю историю: Action
# - самый популярный жанр за всю историю: Action (потом Role-Playing и Adventure)
# - определили топ платформ с 2012 по 2016 год: PS4, XOne, 3DS.
# - определили длительность жизни каждой платформы - это где-то от 5 до 7,6 лет
# - самые популярные жанры за 2012-2016 гг: **Action**,**Role-Playing**, **Sports**, **Adventure**
# - самые популярные жанры за 2012-2016 гг: одна топ-1 в Японии - многопользовательские онлайн игры; в ЕС - экшен, а в Северной Америке - стрелялки.
# - выявили взаимосвязь между оценкой критиков и оценкой пользователей: взаимосвязь в целом есть  от 0,47 до 0,72
# - выявили взаимосвязь между оценкой критиков и продажами: коэф. корр - от 0.32 до 0,42 - взаимосвязь невелика, но некий тренд есть
# - отзывы пользователей не влияют на продажи тех игр, которые они оценивали.
# - возрастной рейтинг влияет на продажи игр по всему миру. Наиболее предпочтительный рейтинг - E, M, T, E10+
#
# - **Проверили 2 гипотезы:**
# - Выявили, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# - Определили, что средние пользовательские рейтинги жанров Action и Sports различаются.
#
#
# - **Факторы, определяющие успешность игры:**
# - платформа выхода игры, лучше выбирать конкретно ту, которая уже сейчас на пике, а таких мало.
# - учитывать рынок сбыта, на какой регион делается ставка
# - стараться получить категорию E, T или M для игры, так больше шансов на ее продажи
# - провести маркетинговую работу с критиками, тогда они могу поставить высокий рейтинг игре, и, таким образом,стимулировать ее спрос.
# -  исходя из всех данных, я бы рекомендовала обратить внимание на PS-4, XOne и 3DS (но ей уже 5 лет, срок ее жизни истекает) и ждать выхода новых платформ.
